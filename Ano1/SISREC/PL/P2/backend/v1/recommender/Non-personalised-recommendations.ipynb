# %%
import pandas as pd
import numpy as np
import scipy as sc
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# ## Data Preparations

# %%
#read csv(s)
movies_df = pd.read_csv("dataset/small_dataset/movies_full_2.csv")
ratings_df = pd.read_csv("dataset/small_dataset/ratings.csv")
tags_df = pd.read_csv("dataset/small_dataset/tags.csv")
links_df = pd.read_csv("dataset/small_dataset/links.csv")

# %%
# print(ratings_df.duplicated)
# print(ratings_df.shape)
# print(ratings_df['userId'].nunique())

# %%
#drop timestamp as it is only consuming memory
ratings_df.drop('timestamp', axis=1, inplace=True)
tags_df.drop('timestamp', axis=1, inplace=True)
#movies_df.drop(columns=(['imdbId', 'url', 'titleLower']), inplace=True)

# %%
movies_df.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres     imdbId    year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  tt0114709  1995.0
# 1                   Adventure|Children|Fantasy  tt0113497  1995.0
# 2                               Comedy|Romance  tt0113228  1995.0
# 3                         Comedy|Drama|Romance  tt0114885  1995.0
# 4                                       Comedy  tt0113041  1995.0
#
#                                                  url  \
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
# 2  https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3  https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4  https://m.media-amazon.com/images/M/MV5BOTEyNz...
#
#                     titleLower
# 0                    toy story
# 1                      jumanji
# 2             grumpier old men
# 3            waiting to exhale
# 4  father of the bride part ii

# %%
movies_2 = movies_df.copy()




movies_df['genres'] = movies_df['genres'].str.split('|')
movies_df['genres'] = movies_df['genres'].apply(lambda x: ', '.join(x)) 
# genres_encoded = movies_df['genres'].str.get_dummies(sep='|')
# movies_df['year'] = movies_df['title'].str.extract('\((\d{4})\)')


# movies_df['year'] = movies_df['year'].astype(int)
movies_df['decade'] = (movies_df['year'] // 10) * 10

movies_df['title'].replace('\((\d{4})\)', '', regex=True, inplace=True)
movies_df.head()


# Flatten the list of genres
movies_2['genres'] = movies_2['genres'].str.split('|')
all_genres = [genre for sublist in movies_2['genres'] for genre in sublist]

# Extract unique genres
unique_genres = list(set(all_genres))

# Sort the unique genres for better readability (optional)
unique_genres.sort()

# Display the unique genres
# print(unique_genres)

del all_genres
del movies_2



# print(len(unique_genres))
# Out:
# C:\Users\João\AppData\Local\Temp\ipykernel_20872\2792258715.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies_df['title'].replace('\((\d{4})\)', '', regex=True, inplace=True)

# %%
print(ratings_df.isnull().sum())
ratings_df.head()
# Out:
# userId     0
# movieId    0
# rating     0
# dtype: int64
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
#print(tags_df.isnull().sum()) #It has 16 null tags
#print(tags_df[tags_df['tag'].isnull()].iloc[0])
tags_df.dropna(inplace=True)
print(tags_df.isnull().sum())
tags_df.head()
# Out:
# userId     0
# movieId    0
# tag        0
# dtype: int64
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %%
print(links_df.isnull().sum())
links_df.head()
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies_rating_user_df = pd.merge(movies_df, ratings_df, on="movieId", how="inner")
movies_rating_user_df.head()
# Out:
#    movieId      title                                           genres  \
# 0        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 1        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 2        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 3        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
# 4        1  Toy Story  Adventure, Animation, Children, Comedy, Fantasy
#
#       imdbId    year                                                url  \
# 0  tt0114709  1995.0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  tt0114709  1995.0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2  tt0114709  1995.0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 3  tt0114709  1995.0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 4  tt0114709  1995.0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
#
#   titleLower  decade  userId  rating
# 0  toy story  1990.0       1     4.0
# 1  toy story  1990.0       5     4.0
# 2  toy story  1990.0       7     4.5
# 3  toy story  1990.0      15     2.5
# 4  toy story  1990.0      17     4.5

# %%
movies_rating_df = movies_rating_user_df[['movieId', 'title', 'rating', 'genres', 'year', 'decade']].groupby(['movieId', 'title', 'genres', 'year', 'decade'])['rating'].agg(['count', 'mean']).round(1)
movies_rating_df.head()
# Out:
#                                                                                                    count  \
# movieId title                       genres                                          year   decade
# 1       Toy Story                   Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0    215
# 2       Jumanji                     Adventure, Children, Fantasy                    1995.0 1990.0    110
# 3       Grumpier Old Men            Comedy, Romance                                 1995.0 1990.0     52
# 4       Waiting to Exhale           Comedy, Drama, Romance                          1995.0 1990.0      7
# 5       Father of the Bride Part II Comedy                                          1995.0 1990.0     49
#
#                                                                                                    mean
# movieId title                       genres                                          year   decade
# 1       Toy Story                   Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0   3.9
# 2       Jumanji                     Adventure, Children, Fantasy                    1995.0 1990.0   3.4
# 3       Grumpier Old Men            Comedy, Romance                                 1995.0 1990.0   3.3
# 4       Waiting to Exhale           Comedy, Drama, Romance                          1995.0 1990.0   2.4
# 5       Father of the Bride Part II Comedy                                          1995.0 1990.0   3.1

# %%
movies_rating_df.sort_values('count', ascending=False, inplace=True)
movies_rating_df.rename(columns={'count' : 'Num_ratings', 'mean': 'Average_rating'}, inplace=True)
movies_rating_df.head(15)
# Out:
#                                                                                                                       Num_ratings  \
# movieId title                                          genres                                          year   decade
# 356     Forrest Gump                                   Comedy, Drama, Romance, War                     1994.0 1990.0          329
# 318     Shawshank Redemption, The                      Crime, Drama                                    1994.0 1990.0          317
# 296     Pulp Fiction                                   Comedy, Crime, Drama, Thriller                  1994.0 1990.0          307
# 593     Silence of the Lambs, The                      Crime, Horror, Thriller                         1991.0 1990.0          279
# 2571    Matrix, The                                    Action, Sci-Fi, Thriller                        1999.0 1990.0          278
# 260     Star Wars: Episode IV - A New Hope             Action, Adventure, Sci-Fi                       1977.0 1970.0          251
# 480     Jurassic Park                                  Action, Adventure, Sci-Fi, Thriller             1993.0 1990.0          238
# 110     Braveheart                                     Action, Drama, War                              1995.0 1990.0          237
# 589     Terminator 2: Judgment Day                     Action, Sci-Fi                                  1991.0 1990.0          224
# 527     Schindler's List                               Drama, War                                      1993.0 1990.0          220
# 2959    Fight Club                                     Action, Crime, Drama, Thriller                  1999.0 1990.0          218
# 1       Toy Story                                      Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0          215
# 1196    Star Wars: Episode V - The Empire Strikes Back Action, Adventure, Sci-Fi                       1980.0 1980.0          211
# 50      Usual Suspects, The                            Crime, Mystery, Thriller                        1995.0 1990.0          204
# 2858    American Beauty                                Drama, Romance                                  1999.0 1990.0          204
#
#                                                                                                                       Average_rating
# movieId title                                          genres                                          year   decade
# 356     Forrest Gump                                   Comedy, Drama, Romance, War                     1994.0 1990.0             4.2
# 318     Shawshank Redemption, The                      Crime, Drama                                    1994.0 1990.0             4.4
# 296     Pulp Fiction                                   Comedy, Crime, Drama, Thriller                  1994.0 1990.0             4.2
# 593     Silence of the Lambs, The                      Crime, Horror, Thriller                         1991.0 1990.0             4.2
# 2571    Matrix, The                                    Action, Sci-Fi, Thriller                        1999.0 1990.0             4.2
# 260     Star Wars: Episode IV - A New Hope             Action, Adventure, Sci-Fi                       1977.0 1970.0             4.2
# 480     Jurassic Park                                  Action, Adventure, Sci-Fi, Thriller             1993.0 1990.0             3.8
# 110     Braveheart                                     Action, Drama, War                              1995.0 1990.0             4.0
# 589     Terminator 2: Judgment Day                     Action, Sci-Fi                                  1991.0 1990.0             4.0
# 527     Schindler's List                               Drama, War                                      1993.0 1990.0             4.2
# 2959    Fight Club                                     Action, Crime, Drama, Thriller                  1999.0 1990.0             4.3
# 1       Toy Story                                      Adventure, Animation, Children, Comedy, Fantasy 1995.0 1990.0             3.9
# 1196    Star Wars: Episode V - The Empire Strikes Back Action, Adventure, Sci-Fi                       1980.0 1980.0             4.2
# 50      Usual Suspects, The                            Crime, Mystery, Thriller                        1995.0 1990.0             4.2
# 2858    American Beauty                                Drama, Romance                                  1999.0 1990.0             4.1

# %% [markdown]
# # Data Preprocessing

# %%
#let's use the beysian average to calculate a more accurate rating
#this is because a review of 5 with only 1 review is worthless, while a 4.2 with multiple reviews is more reliable

def calculate_weighted_rating(df, C, m):
    """
    Calculate Bayesian weighted rating for each movie in the DataFrame.

    Parameters:
    df (DataFrame): DataFrame containing movie ratings.
    C (float): Average rating across all movies (prior assumption).
    m (int): Minimum number of ratings required to be considered.

    Returns:
    DataFrame: DataFrame with Bayesian weighted rating column added.
    """
    
    # Add the Bayesian weighted rating as a new column in the DataFrame
    df['Bayesian_rating'] = (df['Num_ratings'] / (df['Num_ratings'] + m)) * df['Average_rating'] + (m / (df['Num_ratings'] + m)) * C

    return df

C = round(ratings_df['rating'].mean(), 2)
movies_rating_df = calculate_weighted_rating(movies_rating_df, C, 500)
movies_rating_df.drop(columns='Average_rating', inplace=True)
movies_rating_df.sort_values(by='Bayesian_rating', ascending=False, inplace=True)
movies_rating_df.head()
# Out:
#                                                                                 Num_ratings  \
# movieId title                     genres                         year   decade
# 318     Shawshank Redemption, The Crime, Drama                   1994.0 1990.0          317
# 356     Forrest Gump              Comedy, Drama, Romance, War    1994.0 1990.0          329
# 296     Pulp Fiction              Comedy, Crime, Drama, Thriller 1994.0 1990.0          307
# 593     Silence of the Lambs, The Crime, Horror, Thriller        1991.0 1990.0          279
# 2571    Matrix, The               Action, Sci-Fi, Thriller       1999.0 1990.0          278
#
#                                                                                 Bayesian_rating
# movieId title                     genres                         year   decade
# 318     Shawshank Redemption, The Crime, Drama                   1994.0 1990.0         3.849204
# 356     Forrest Gump              Comedy, Drama, Romance, War    1994.0 1990.0         3.777805
# 296     Pulp Fiction              Comedy, Crime, Drama, Thriller 1994.0 1990.0         3.766295
# 593     Silence of the Lambs, The Crime, Horror, Thriller        1991.0 1990.0         3.750706
# 2571    Matrix, The               Action, Sci-Fi, Thriller       1999.0 1990.0         3.750129

# %% [markdown]
# # Non-personalized Recommendation System

# %% [markdown]
# ### This will be applied to the website if there isn't any user information, aka, one is not logged in.
#
# Despite not being logged in, recommendations will be provided such as:
# - Best movies overall
# - Best movies for each genre
# - Spoting trends
# - etc

# %%
# let's recommend the best movies of all time (doesn't matter the genre, only it's popularity)
def non_personalized_recommendations_overall_rating(num_movies, df):
    movies_best = df.copy()
    movies_best = movies_best.iloc[:num_movies]
    movies_best.reset_index(inplace=True)
    
    return movies_best[['movieId', 'title', 'Num_ratings', 'Bayesian_rating']]

print(non_personalized_recommendations_overall_rating(10, movies_rating_df))
# Out:
#    movieId                                           title  Num_ratings  \
# 0      318                       Shawshank Redemption, The          317
# 1      356                                    Forrest Gump          329
# 2      296                                    Pulp Fiction          307
# 3      593                       Silence of the Lambs, The          279
# 4     2571                                     Matrix, The          278
# 5     2959                                      Fight Club          218
# 6      260              Star Wars: Episode IV - A New Hope          251
# 7      858                                  Godfather, The          192
# 8      527                                Schindler's List          220
# 9     1196  Star Wars: Episode V - The Empire Strikes Back          211
#
#    Bayesian_rating
# 0         3.849204
# 1         3.777805
# 2         3.766295
# 3         3.750706
# 4         3.750129
# 5         3.742897
# 6         3.733955
# 7         3.721965
# 8         3.713889
# 9         3.707736

# %%
#unique_genres is a list with all available genres

# Function to find the best movie for each genre
def find_best_movies_for_genres(df, possible_genres, num_of_movies):
    df_copy = df.copy()
    df_copy.reset_index(inplace=True)
    df_copy['genres'] = df_copy['genres'].str.split(', ')
    best_movies_for_genres = {}
    for genre in possible_genres:
        # Filter DataFrame by genre

        genre_df = df_copy[df_copy['genres'].apply(lambda x: genre in x)]
        if not genre_df.empty:
           
            # Select the top movie for the genre
            best_movie = genre_df[['movieId', 'title', 'Num_ratings', 'Bayesian_rating']].iloc[:num_of_movies]
            best_movies_for_genres[genre] = best_movie
    del df_copy
    del genre_df
    return best_movies_for_genres

# Find the best movie for each genre
best_movies_for_genres = find_best_movies_for_genres(movies_rating_df, unique_genres, 10)

# Display the best movies for each genre
for genre, movie in best_movies_for_genres.items():
    print(f"Best movie for genre '{genre}':")
    print(movie[['movieId', 'title']])
    print()
# Out:
# Best movie for genre '(no genres listed)':
#       movieId                                              title
# 1172   166024                                           Whiplash
# 1341   122896   Pirates of the Caribbean: Dead Men Tell No Tales
# 1359   171495                                             Cosmos
# 1588   176601                                       Black Mirror
# 1607   147250  The Adventures of Sherlock Holmes and Doctor W...
# 1696   171749                              Death Note: Desu nôto
# 2123   169034                                           Lemonade
# 2201   159161                               Ali Wong: Baby Cobra
# 2220   173535  The Adventures of Sherlock Holmes and Doctor W...
# 2291   156605                                           Paterson
#
# Best movie for genre 'Action':
#     movieId                                              title
# 4      2571                                        Matrix, The
# 5      2959                                         Fight Club
# 6       260                 Star Wars: Episode IV - A New Hope
# 9      1196     Star Wars: Episode V - The Empire Strikes Back
# 11     1198  Raiders of the Lost Ark (Indiana Jones and the...
# 14     1210         Star Wars: Episode VI - Return of the Jedi
# 16     2028                                Saving Private Ryan
# 17     7153     Lord of the Rings: The Return of the King, The
# 18      110                                         Braveheart
# 19    58559                                   Dark Knight, The
#
# Best movie for genre 'Adventure':
#     movieId                                              title
# 6       260                 Star Wars: Episode IV - A New Hope
# 9      1196     Star Wars: Episode V - The Empire Strikes Back
# 11     1198  Raiders of the Lost Ark (Indiana Jones and the...
# 13     4993  Lord of the Rings: The Fellowship of the Ring,...
# 14     1210         Star Wars: Episode VI - Return of the Jedi
# 17     7153     Lord of the Rings: The Return of the King, The
# 21     1197                                Princess Bride, The
# 23     1136                    Monty Python and the Holy Grail
# 33     5952             Lord of the Rings: The Two Towers, The
# 39     1270                                 Back to the Future
#
# Best movie for genre 'Animation':
#      movieId                                          title
# 41         1                                      Toy Story
# 46      6377                                   Finding Nemo
# 54      5618  Spirited Away (Sen to Chihiro no kamikakushi)
# 55     60069                                         WALL·E
# 57       364                                 Lion King, The
# 60      4306                                          Shrek
# 73     68954                                             Up
# 76      4886                                 Monsters, Inc.
# 81       588                                        Aladdin
# 103      595                           Beauty and the Beast
#
# Best movie for genre 'Children':
#      movieId                                title
# 41         1                            Toy Story
# 46      6377                         Finding Nemo
# 55     60069                               WALL·E
# 57       364                       Lion King, The
# 60      4306                                Shrek
# 73     68954                                   Up
# 76      4886                       Monsters, Inc.
# 81       588                              Aladdin
# 85      1073  Willy Wonka & the Chocolate Factory
# 103      595                 Beauty and the Beast
#
# Best movie for genre 'Comedy':
#     movieId                                              title
# 1       356                                       Forrest Gump
# 2       296                                       Pulp Fiction
# 20      608                                              Fargo
# 21     1197                                Princess Bride, The
# 23     1136                    Monty Python and the Holy Grail
# 34     4973      Amelie (Fabuleux destin d'Amélie Poulain, Le)
# 38      750  Dr. Strangelove or: How I Learned to Stop Worr...
# 39     1270                                 Back to the Future
# 41        1                                          Toy Story
# 46     6377                                       Finding Nemo
#
# Best movie for genre 'Crime':
#     movieId                      title
# 0       318  Shawshank Redemption, The
# 2       296               Pulp Fiction
# 3       593  Silence of the Lambs, The
# 5      2959                 Fight Club
# 7       858             Godfather, The
# 10       50        Usual Suspects, The
# 15     1221    Godfather: Part II, The
# 19    58559           Dark Knight, The
# 20      608                      Fargo
# 25     1089             Reservoir Dogs
#
# Best movie for genre 'Documentary':
#      movieId                                              title
# 190      246                                        Hoop Dreams
# 281     5669                              Bowling for Columbine
# 396      162                                              Crumb
# 438     7156  Fog of War: Eleven Lessons from the Life of Ro...
# 473    80906                                         Inside Job
# 502     2064                                         Roger & Me
# 637    77455                         Exit Through the Gift Shop
# 724     1189                                Thin Blue Line, The
# 753     6331                                         Spellbound
# 761     1192                                   Paris Is Burning
#
# Best movie for genre 'Drama':
#     movieId                                           title
# 0       318                       Shawshank Redemption, The
# 1       356                                    Forrest Gump
# 2       296                                    Pulp Fiction
# 5      2959                                      Fight Club
# 7       858                                  Godfather, The
# 8       527                                Schindler's List
# 12     2858                                 American Beauty
# 15     1221                         Godfather: Part II, The
# 16     2028                             Saving Private Ryan
# 17     7153  Lord of the Rings: The Return of the King, The
#
# Best movie for genre 'Fantasy':
#     movieId                                              title
# 13     4993  Lord of the Rings: The Fellowship of the Ring,...
# 17     7153     Lord of the Rings: The Return of the King, The
# 21     1197                                Princess Bride, The
# 23     1136                    Monty Python and the Holy Grail
# 33     5952             Lord of the Rings: The Two Towers, The
# 41        1                                          Toy Story
# 54     5618      Spirited Away (Sen to Chihiro no kamikakushi)
# 60     4306                                              Shrek
# 72     1265                                      Groundhog Day
# 76     4886                                     Monsters, Inc.
#
# Best movie for genre 'Film-Noir':
#      movieId                                   title
# 63      1617                       L.A. Confidential
# 92      1252                               Chinatown
# 135    32587                                Sin City
# 139      913                     Maltese Falcon, The
# 210      922  Sunset Blvd. (a.k.a. Sunset Boulevard)
# 273     1212                          Third Man, The
# 328     4848                        Mulholland Drive
# 339     1245                       Miller's Crossing
# 340      930                               Notorious
# 346     3435                        Double Indemnity
#
# Best movie for genre 'Horror':
#      movieId                      title
# 3        593  Silence of the Lambs, The
# 45      1214                      Alien
# 50      1258               Shining, The
# 51      2762           Sixth Sense, The
# 61      1200                     Aliens
# 84      1387                       Jaws
# 98      1219                     Psycho
# 105     8874          Shaun of the Dead
# 155     6502              28 Days Later
# 178     1215           Army of Darkness
#
# Best movie for genre 'IMAX':
#      movieId                                     title
# 19     58559                          Dark Knight, The
# 35     79132                                 Inception
# 57       364                            Lion King, The
# 74       150                                 Apollo 13
# 88     33794                             Batman Begins
# 103      595                      Beauty and the Beast
# 106    44191                            V for Vendetta
# 108    91529                    Dark Knight Rises, The
# 113   109487                              Interstellar
# 115     8368  Harry Potter and the Prisoner of Azkaban
#
# Best movie for genre 'Musical':
#      movieId                                 title
# 57       364                        Lion King, The
# 81       588                               Aladdin
# 85      1073   Willy Wonka & the Chocolate Factory
# 103      595                  Beauty and the Beast
# 117      919                     Wizard of Oz, The
# 153     2700  South Park: Bigger, Longer and Uncut
# 160      899                   Singin' in the Rain
# 166     1028                          Mary Poppins
# 182     1035                   Sound of Music, The
# 198     1220                   Blues Brothers, The
#
# Best movie for genre 'Mystery':
#     movieId                               title
# 10       50                 Usual Suspects, The
# 25     1089                      Reservoir Dogs
# 27     4226                             Memento
# 28       47                Seven (a.k.a. Se7en)
# 35    79132                           Inception
# 37       32  Twelve Monkeys (a.k.a. 12 Monkeys)
# 44      904                         Rear Window
# 51     2762                    Sixth Sense, The
# 63     1617                   L.A. Confidential
# 71     4878                        Donnie Darko
#
# Best movie for genre 'Romance':
#     movieId                                          title
# 1       356                                   Forrest Gump
# 12     2858                                American Beauty
# 21     1197                            Princess Bride, The
# 26     7361          Eternal Sunshine of the Spotless Mind
# 34     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le)
# 36     1704                              Good Will Hunting
# 43      912                                     Casablanca
# 55    60069                                         WALL·E
# 60     4306                                          Shrek
# 62     4995                              Beautiful Mind, A
#
# Best movie for genre 'Sci-Fi':
#     movieId                                           title
# 4      2571                                     Matrix, The
# 6       260              Star Wars: Episode IV - A New Hope
# 9      1196  Star Wars: Episode V - The Empire Strikes Back
# 14     1210      Star Wars: Episode VI - Return of the Jedi
# 22      589                      Terminator 2: Judgment Day
# 26     7361           Eternal Sunshine of the Spotless Mind
# 35    79132                                       Inception
# 37       32              Twelve Monkeys (a.k.a. 12 Monkeys)
# 39     1270                              Back to the Future
# 42      541                                    Blade Runner
#
# Best movie for genre 'Thriller':
#     movieId                      title
# 2       296               Pulp Fiction
# 3       593  Silence of the Lambs, The
# 4      2571                Matrix, The
# 5      2959                 Fight Club
# 10       50        Usual Suspects, The
# 20      608                      Fargo
# 25     1089             Reservoir Dogs
# 27     4226                    Memento
# 28       47       Seven (a.k.a. Se7en)
# 30    48516              Departed, The
#
# Best movie for genre 'War':
#      movieId                                              title
# 1        356                                       Forrest Gump
# 8        527                                   Schindler's List
# 16      2028                                Saving Private Ryan
# 18       110                                         Braveheart
# 38       750  Dr. Strangelove or: How I Learned to Stop Worr...
# 40      1208                                     Apocalypse Now
# 58      1222                                  Full Metal Jacket
# 69      2324                Life Is Beautiful (La Vita è bella)
# 70     68157                               Inglourious Basterds
# 107     1204                                 Lawrence of Arabia
#
# Best movie for genre 'Western':
#      movieId                                              title
# 87      1201  Good, the Bad and the Ugly, The (Buono, il bru...
# 90       590                                 Dances with Wolves
# 164    99114                                   Django Unchained
# 168     1266                                         Unforgiven
# 187     3671                                    Blazing Saddles
# 189     1304                 Butch Cassidy and the Sundance Kid
# 197     3681  For a Few Dollars More (Per qualche dollaro in...
# 251      553                                          Tombstone
# 278    56782                                There Will Be Blood
# 306     2951    Fistful of Dollars, A (Per un pugno di dollari)

# %%
#unique_genres is a list with all available genres

# Function to find the best movie for each genre
def find_best_movies_for_genres(df, genre, num_of_movies):
    df_copy = df.copy()
    df_copy.reset_index(inplace=True)
    df_copy['genres'] = df_copy['genres'].str.split(', ')
    best_movies_for_genres = {}
   

    genre_df = df_copy[df_copy['genres'].apply(lambda x: genre in x)]
    if not genre_df.empty:
        
        # Select the top movie for the genre
        best_movie = genre_df[['movieId', 'title','genres', 'Num_ratings', 'Bayesian_rating']].iloc[:num_of_movies]
        best_movies_for_genres[genre] = best_movie
    del df_copy
    del genre_df
    return best_movies_for_genres

# Find the best movie for each genre
#print(movies_rating_df)
genre = 'Crime'
best_movies_for_genres = find_best_movies_for_genres(movies_rating_df, genre, 10)
#print(best_movies_for_genres)

# Display the best movies for each genre

print(f"Best movie for genre '{genre}':")
movie_genre_df = best_movies_for_genres[genre][['movieId', 'title','genres', 'Num_ratings', 'Bayesian_rating']]
movie_genre_df.head()
# Out:
# Best movie for genre 'Crime':
#    movieId                      title                            genres  \
# 0      318  Shawshank Redemption, The                    [Crime, Drama]
# 2      296               Pulp Fiction  [Comedy, Crime, Drama, Thriller]
# 3      593  Silence of the Lambs, The         [Crime, Horror, Thriller]
# 5     2959                 Fight Club  [Action, Crime, Drama, Thriller]
# 7      858             Godfather, The                    [Crime, Drama]
#
#    Num_ratings  Bayesian_rating
# 0          317         3.849204
# 2          307         3.766295
# 3          279         3.750706
# 5          218         3.742897
# 7          192         3.721965

# %%
#best movies of a given year

def recommend_movies_best_year(df, year, num_movies):
    movies_year = df.copy()
    movies_year.reset_index(inplace=True)
    movies_year = movies_year[movies_year['year'] == year]
    movies_year_best = movies_year.iloc[:num_movies]
    del movies_year 
    
    
    return movies_year_best[['movieId', 'title', 'Num_ratings', 'Bayesian_rating', 'year']]

    
best_year_movies = recommend_movies_best_year(movies_rating_df, 2010, 10)
best_year_movies.head()
# Out:
#      movieId                                         title  Num_ratings  \
# 35     79132                                     Inception          143
# 127    78499                                   Toy Story 3           55
# 129    74458                                Shutter Island           67
# 156    81845                            King's Speech, The           58
# 199    81834  Harry Potter and the Deathly Hallows: Part 1           47
#
#      Bayesian_rating    year
# 35          3.633437  2010.0
# 127         3.559459  2010.0
# 129         3.559083  2010.0
# 156         3.551971  2010.0
# 199         3.542962  2010.0

# %%
#recommend the bets movies of a given decade

def recommend_movies_best_decade(df, decade, num_movies):
    movies_decade = df.copy()
    movies_decade.reset_index(inplace=True)
    movies_decade = movies_decade[movies_decade['decade'] == decade]
    movies_decade_best = movies_decade.iloc[:num_movies]
    del movies_decade 
    
    
    return movies_decade_best[['movieId', 'title', 'Num_ratings', 'Bayesian_rating', 'decade']]#'decade','year',  'Bayesian_rating']]

    
best_year_movies = recommend_movies_best_decade(movies_rating_df, 2010, 10)
best_year_movies.head()
# Out:
#      movieId                    title  Num_ratings  Bayesian_rating  decade
# 35     79132                Inception          143         3.633437  2010.0
# 108    91529   Dark Knight Rises, The           76         3.565972  2010.0
# 113   109487             Interstellar           73         3.563700  2010.0
# 114   112852  Guardians of the Galaxy           59         3.563327  2010.0
# 127    78499              Toy Story 3           55         3.559459  2010.0
